# %%
from lib import cma_es

# %%
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

dim = 2

m = [0 for _ in range(dim)]
C = np.identity(dim)
C_dash = [[3, 5], 
          [0, 1]]

value = np.random.multivariate_normal(mean=m, cov=C_dash, size=200)

plt.show(sns.scatterplot(x=value[:,0], y=value[:,1]))
# Out:
# C:\Users\taise\AppData\Local\Temp\ipykernel_14304\258890609.py:12: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   value = np.random.multivariate_normal(mean=m, cov=C_dash, size=200)

# %%
def obj_func(x):
    return x * x + 1

loss, value = cma_es(obj_func, [(-4, 5)], ["x"])

print(f"最適化結果: \n解={loss}, 値={value}")
# Out:
# 最適化結果:
# 解=1.1928762466421952, 値=[-0.4391767829043278]

# %%
def parametric_func(x, y, a=1, b=1):
        return a * (x - 1)**2 + b * (y - 2)**2

loss, value = cma_es(
        parametric_func, 
        [(-5, 5), (-5, 5)], 
        ["x", "y"], 
)

print(f"最適化結果: \n解={loss}, 値={value}")
# Out:
# 最適化結果:
# 解=0.5457548261820824, 値=[1.286326603137196, 2.681008004738562]

# %%
def rosenbrock(x, y, z):
        return (1 - x)**2 + 100*(y - x**2)**2 + (z - 1)**2
    
bounds = [(-2, 2), (-2, 2), (-2, 2)]
loss, value = cma_es(rosenbrock, bounds, ["x", "y", "z"], max_iter=2000)

print(f"Rosenbrock関数の最適化結果: \n解={loss}, 値={value}")
# Out:
# Rosenbrock関数の最適化結果:
# 解=8.79602105740009, 値=[0.07355230298628168, -0.17111036071872343, -1.195853824943081]
